# %% [markdown]
# <a href="https://colab.research.google.com/github/ddlandim/monografy-ann-demand-prediction/blob/master/case1_ModelsTests_DriverCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
prefix = 'case1_'
path = 'https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/'
sufix = '?raw=true'

# %% [markdown]
# # **BIBLIOTECAS**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
plt.style.use('ggplot')
# PROCESSAMENTO
from sklearn.preprocessing import *
from sklearn.metrics import *
# MODELOS
from tensorflow import keras
from keras import layers
from keras.callbacks import EarlyStopping, ModelCheckpoint

import seaborn as sns
import scipy

# EXPORTAÇÃO / IMPORTAÇÃO
# Lib para exportar scalers
# https://scikit-learn.org/stable/modules/model_persistence.html
from joblib import dump, load

# Lib para exportar numpy ou arrays
# https://www.christopherlovell.co.uk/blog/2016/04/27/h5py-intro.html
import h5py

# %% [markdown]
# # IMPORTAÇÃO DOS DADOS

# %% [markdown]
# ## Teste de indexação e inclusão de features em um dataframe com as métricas das avaliações.

# %%
df_models_metrics = pd.DataFrame(columns=['MODELO','TOTAL_CONSUMIDAS','TOTAL_PREVISTAS','ERRO_TOTAL_PREVISAO','ERRO_TOTAL_PERC_PREVISAO', 'CORRELACAO', 'pi', 'RMSE', 'TOTAL_FALTA', 'TOTAL_DESCARTE', 'ERRO_ABS_MEDIANO' , 'ERRO_ABSOLUTO_PERCENTUAL_MEDIO'])
df_models_metrics
# Out:
# Empty DataFrame
# Columns: [MODELO, TOTAL_CONSUMIDAS, TOTAL_PREVISTAS, ERRO_TOTAL_PREVISAO, ERRO_TOTAL_PERC_PREVISAO, CORRELACAO, pi, RMSE, TOTAL_FALTA, TOTAL_DESCARTE, ERRO_ABS_MEDIANO, ERRO_ABSOLUTO_PERCENTUAL_MEDIO]
# Index: []

# %%
df_models_metrics = df_models_metrics.set_index('MODELO')
df_models_metrics
# Out:
# Empty DataFrame
# Columns: [TOTAL_CONSUMIDAS, TOTAL_PREVISTAS, ERRO_TOTAL_PREVISAO, ERRO_TOTAL_PERC_PREVISAO, CORRELACAO, pi, RMSE, TOTAL_FALTA, TOTAL_DESCARTE, ERRO_ABS_MEDIANO, ERRO_ABSOLUTO_PERCENTUAL_MEDIO]
# Index: []

# %%
new_row = pd.Series(data={ 'TOTAL_CONSUMIDAS':87, 
           'TOTAL_PREVISTAS':92, 
           'ERRO_TOTAL_PREVISAO':97,
           'ERRO_TOTAL_PERC_PREVISAO':100,
           'CORRELACAO':97, 
           'pi':97, 
           'RMSE':97, 
           'TOTAL_FALTA':97, 
           'TOTAL_DESCARTE':97, 
           'ERRO_ABS_MEDIANO':97, 
           'ERRO_ABSOLUTO_PERCENTUAL_MEDIO':97}, 
           name = 'dummy')
df_models_metrics = df_models_metrics.append(new_row, ignore_index=False)
df_models_metrics
# Out:
#        TOTAL_CONSUMIDAS  ... ERRO_ABSOLUTO_PERCENTUAL_MEDIO
# MODELO                   ...
# dummy                87  ...                             97
#
# [1 rows x 11 columns]

# %%
df_models_metrics.drop('dummy', inplace = True)
df_models_metrics
# Out:
# Empty DataFrame
# Columns: [TOTAL_CONSUMIDAS, TOTAL_PREVISTAS, ERRO_TOTAL_PREVISAO, ERRO_TOTAL_PERC_PREVISAO, CORRELACAO, pi, RMSE, TOTAL_FALTA, TOTAL_DESCARTE, ERRO_ABS_MEDIANO, ERRO_ABSOLUTO_PERCENTUAL_MEDIO]
# Index: []

# %% [markdown]
# ## **case1_** CONJUNTO DE TESTE = 2019-01-01 À 2019-07-31

# %%
df_test = pd.read_pickle("https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_df_test.pkl?raw=true")
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 88 entries, 2019-02-20 to 2019-07-05
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SEMESTRE_1                88 non-null     int64
#  1   SEMESTRE_2                88 non-null     int64
#  2   SEGUNDA                   88 non-null     int64
#  3   TERCA                     88 non-null     int64
#  4   QUARTA                    88 non-null     int64
#  5   QUINTA                    88 non-null     int64
#  6   SEXTA                     88 non-null     int64
#  7   DISTANCIA_DIA_ANTERIOR    88 non-null     int64
#  8   DISTANCIA_DIA_POSTERIOR   88 non-null     int64
#  9   PERC_CONCLUSAO_SEM        88 non-null     float64
#  10  PERC_CONCLUSAO_MES        88 non-null     float64
#  11  PRESSAO_ATMOSFERICA       88 non-null     float64
#  12  TEMPERATURA               88 non-null     float64
#  13  UMIDADE                   88 non-null     int64
#  14  VENTO                     88 non-null     float64
#  15  VENDAS_ALMOCO             88 non-null     int64
#  16  VENDAS_ALMOCO_1           88 non-null     int64
#  17  VENDAS_ALMOCO_2           88 non-null     int64
#  18  VENDAS_ALMOCO_3           88 non-null     int64
#  19  VENDAS_ALMOCO_4           88 non-null     int64
#  20  VENDAS_ALMOCO_5           88 non-null     int64
#  21  ENTR_ALMOCO               88 non-null     int64
#  22  ENTR_ALMOCO_1             88 non-null     int64
#  23  ENTR_ALMOCO_2             88 non-null     int64
#  24  ENTR_ALMOCO_3             88 non-null     int64
#  25  ENTR_ALMOCO_4             88 non-null     int64
#  26  ENTR_ALMOCO_5             88 non-null     int64
#  27  ENTR_JANTAR               88 non-null     int64
#  28  ENTR_JANTAR_1             88 non-null     int64
#  29  ENTR_JANTAR_2             88 non-null     int64
#  30  ENTR_JANTAR_3             88 non-null     int64
#  31  ENTR_JANTAR_4             88 non-null     int64
#  32  ENTR_JANTAR_5             88 non-null     int64
#  33  RU_ALMOCO_PRED            88 non-null     int64
#  34  RU_JANTAR_PRED            88 non-null     int64
#  35  pred_RNN_ENDO_1_NEW_test  88 non-null     float32
#  36  pred_RNN_ENDO_1_test      88 non-null     float32
#  37  model_rnn_unique_1        88 non-null     float32
#  38  pred_RNN_ENDO_2_test      88 non-null     float32
#  39  pred_MLP_ENDO_1_test      88 non-null     float32
#  40  pred_RNN_EXO_1_test       88 non-null     float32
#  41  pred_RNN_EXO_2_test       88 non-null     float32
#  42  pred_RNN_EXO_3_test       88 non-null     float32
# dtypes: float32(8), float64(5), int64(30)
# memory usage: 27.5 KB

# %%
df_test.head()
# Out:
#             SEMESTRE_1  SEMESTRE_2  ...  pred_RNN_EXO_2_test  pred_RNN_EXO_3_test
# DATA                                ...
# 2019-02-20           1           0  ...           387.503998           345.411926
# 2019-02-21           1           0  ...           388.437286           238.454773
# 2019-02-22           1           0  ...           348.338806           283.864624
# 2019-02-25           1           0  ...           226.436798           311.131470
# 2019-02-26           1           0  ...           258.375458           318.834534
#
# [5 rows x 43 columns]

# %%
df_test.tail()
# Out:
#             SEMESTRE_1  SEMESTRE_2  ...  pred_RNN_EXO_2_test  pred_RNN_EXO_3_test
# DATA                                ...
# 2019-07-01           1           0  ...           230.292511           341.280792
# 2019-07-02           1           0  ...           178.844284           313.745209
# 2019-07-03           1           0  ...           156.752350           295.456299
# 2019-07-04           1           0  ...           174.423935           277.832916
# 2019-07-05           1           0  ...            18.642702           225.450211
#
# [5 rows x 43 columns]

# %%
df_test['ENTR_ALMOCO'].plot()

# %% [markdown]
# ## NP ARRAYS ESCALADOS E FORMATADOS PARA ENTRADA DOS MODELOS

# %%
# !wget https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_np_data.h5?raw=true
# Out:
# --2020-09-27 04:33:22--  https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_np_data.h5?raw=true
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_np_data.h5 [following]
# --2020-09-27 04:33:23--  https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_np_data.h5
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_np_data.h5 [following]
# --2020-09-27 04:33:23--  https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_np_data.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 91784 (90K) [application/octet-stream]
# Saving to: ‘case1_np_data.h5?raw=true.1’
#
# case1_np_data.h5?ra 100%[===================>]  89.63K  --.-KB/s    in 0.01s
#
# 2020-09-27 04:33:23 (5.84 MB/s) - ‘case1_np_data.h5?raw=true.1’ saved [91784/91784]

# %%
hf = h5py.File('./case1_np_data.h5?raw=true', 'r')
hf.keys()
# Out:
# <KeysViewHDF5 ['scaled_test_x', 'scaled_test_y', 'scaled_train_x', 'scaled_train_y', 'scaled_val_x', 'scaled_val_y', 'test_x_dense', 'train_x_dense', 'val_x_dense']>

# %%
# Dados Recorrentes(temporais), escalados
scaled_recurrent_train_x = np.array(hf.get('scaled_train_x'))
scaled_recurrent_val_x = np.array(hf.get('scaled_val_x'))
scaled_recurrent_test_x = np.array(hf.get('scaled_test_x'))

# Dados Categóricos (dias da semana e semestre já escalados no df original)
# concatenados com Dados Pontuais (climáticos) escalados
scaled_discrete_train_x = np.array(hf.get('train_x_dense'))
scaled_discrete_val_x = np.array(hf.get('val_x_dense'))
scaled_discrete_test_x = np.array(hf.get('test_x_dense'))

# Valores de supervisão (saída) de cada dataframe, escalados
scaled_train_y = np.array(hf.get('scaled_train_y'))
scaled_val_y = np.array(hf.get('scaled_val_y'))
scaled_test_y = np.array(hf.get('scaled_test_y'))

# %%
hf.close()

# %% [markdown]
# ## Importando Scalers para transformar a saída em valores reais.

# %%
# !wget https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_scaler_numpont.joblib?raw=true
# Out:
# --2020-09-27 04:33:23--  https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_scaler_numpont.joblib?raw=true
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_scaler_numpont.joblib [following]
# --2020-09-27 04:33:23--  https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_scaler_numpont.joblib
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_scaler_numpont.joblib [following]
# --2020-09-27 04:33:23--  https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_scaler_numpont.joblib
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 908 [application/octet-stream]
# Saving to: ‘case1_scaler_numpont.joblib?raw=true.1’
#
# case1_scaler_numpon 100%[===================>]     908  --.-KB/s    in 0s
#
# 2020-09-27 04:33:23 (62.3 MB/s) - ‘case1_scaler_numpont.joblib?raw=true.1’ saved [908/908]

# %%
# !wget https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_rnn_scalers_arr.joblib?raw=true
# Out:
# --2020-09-27 04:33:23--  https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_rnn_scalers_arr.joblib?raw=true
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_rnn_scalers_arr.joblib [following]
# --2020-09-27 04:33:24--  https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_rnn_scalers_arr.joblib
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_rnn_scalers_arr.joblib [following]
# --2020-09-27 04:33:24--  https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_rnn_scalers_arr.joblib
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1141 (1.1K) [application/octet-stream]
# Saving to: ‘case1_rnn_scalers_arr.joblib?raw=true.1’
#
# case1_rnn_scalers_a 100%[===================>]   1.11K  --.-KB/s    in 0s
#
# 2020-09-27 04:33:24 (60.5 MB/s) - ‘case1_rnn_scalers_arr.joblib?raw=true.1’ saved [1141/1141]

# %%
num_temporais = 3 #ENTR_ALMOCO, VENDAS_ALMOCO, ENTR_JANTAR
discrete_scaler = MinMaxScaler([0,1])
discrete_scaler = load('./case1_scaler_numpont.joblib?raw=true')

recurrent_scalers = [MinMaxScaler([0,1]) for i in range(num_temporais)]
recurrent_scalers = load('./case1_rnn_scalers_arr.joblib?raw=true')

# %% [markdown]
# # **FUNÇÕES DE AVALIAÇÃO DOS MODELOS**

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
  y_true = np.maximum(y_true, 1e-7)  # Prevent division by zero
  return 100. * np.mean(np.abs((y_true - y_pred) / y_true))

def metricas_predicoes(_df_true,_predStr,_df_models_metrics):
  m_df_models_metrics = pd.DataFrame()
  m_df_models_metrics = _df_models_metrics
  df = pd.DataFrame()
  df = _df_true

  arr_true = df['ENTR_ALMOCO']
  sum_true = np.sum(arr_true)
  len_true = len(arr_true)

  arr_pred = df[_predStr]
  sum_pred = np.sum(arr_pred)
  len_pred = len(arr_pred)

  diff_pred = sum_pred - sum_true
  perc_diff_pred = (diff_pred / max(1e-7,sum_true)) * 100

  arr_e = arr_true - arr_pred

  print("TOTAL DE REFEIÇÕES CONSUMIDAS = " + str(sum_true) + " : " + str(len_true) + " linhas")
  print("TOTAL DE REFEIÇÕES PROJETADAS = " + str(sum_pred) + " : " + str(len_pred) + " linhas")
  print("ERRO DE PREVISÃO = " + str(diff_pred) + " " + str(perc_diff_pred) + " % do total consumido")

  m_r, m_p = scipy.stats.pearsonr(arr_true, arr_pred)
  print("CORRELAÇÃO (r): " + str(m_r) + " Pi (p) :" + str(m_p))
  sns.regplot(x=arr_true,y=arr_pred,data=df)

  rmse = mean_squared_error(arr_true, arr_pred, squared=False)
  print("RMSE = " + str(rmse))

  m_mae = np.median(np.abs(arr_e))
  m_mape = mean_absolute_percentage_error(arr_true,arr_pred)

  subpredictions = sum(i for i in arr_e if i < 0)
  superpredictions = sum(i for i in arr_e if i >= 0)

  print("TOTAL DE REFEIÇÕES SUB PROJETADAS = " + str(subpredictions))
  print("TOTAL DE REFEIÇÕES SUPER PROJETADAS = " + str(superpredictions))
  print("ERRO ABSOLUTO MEDIANO = " + str(m_mae))
  print("ERRO ABSOLUTO PERCENTUAL MEDIO = " + str(m_mape)+"%")
  plt.figure(figsize=(30,5))
  df['ENTR_ALMOCO'].plot( linewidth=1.5, color='red', label = 'ALMOÇO REAL')
  df[_predStr].plot( linewidth=2.5, color='blue', label = 'ALMOÇO PREVISTO')
  plt.legend()
  plt.xlabel("Index", labelpad=15)
  plt.show()
  #['MODELO','TOTAL_CONSUMIDAS','TOTAL_PROJETADAS','ERRO_PROJECAO', 'CORRELACAO', 'pi', 'RMSE', 'TOTAL SUBPROJETADO', 'TOTAL SUPER PROJETADO ', 'ERRO ABS MEDIANO' , 'ERRO ABSOLUTO PERCENTUAL MEDIO']
  new_row = pd.Series(data={ 'TOTAL_CONSUMIDAS':sum_true, 
          'TOTAL_PREVISTAS':sum_pred, 
          'ERRO_TOTAL_PREVISAO':diff_pred,
          'ERRO_TOTAL_PERC_PREVISAO':perc_diff_pred,
          'CORRELACAO':m_r, 
          'pi':m_p, 
          'RMSE':rmse, 
          'TOTAL_FALTA':subpredictions, 
          'TOTAL_DESCARTE':superpredictions, 
          'ERRO_ABS_MEDIANO':m_mae, 
          'ERRO_ABSOLUTO_PERCENTUAL_MEDIO':m_mape}, 
          name = _predStr)
  m_df_models_metrics = m_df_models_metrics.append(new_row, ignore_index=False)
  return m_df_models_metrics

# %% [markdown]
# # **PREVISÕES**

# %% [markdown]
# ## IMPORTAÇÃO DOS MODELOS ENDÓGENOS

# %%
# !wget https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_MLP_ENDO_1_validated.h5?raw=true
# !wget https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_RNN_ENDO_1_validated.h5?raw=true
# !wget https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_RNN_ENDO_1_NEW_validated.h5?raw=true
# !wget https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_RNN_ENDO_2_validated.h5?raw=true
# Out:
# --2020-09-27 04:33:24--  https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_MLP_ENDO_1_validated.h5?raw=true
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_MLP_ENDO_1_validated.h5 [following]
# --2020-09-27 04:33:24--  https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_MLP_ENDO_1_validated.h5
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_MLP_ENDO_1_validated.h5 [following]
# --2020-09-27 04:33:24--  https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_MLP_ENDO_1_validated.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70216 (69K) [application/octet-stream]
# Saving to: ‘case1_MLP_ENDO_1_validated.h5?raw=true’
#
# case1_MLP_ENDO_1_va 100%[===================>]  68.57K  --.-KB/s    in 0.02s
#
# 2020-09-27 04:33:24 (4.26 MB/s) - ‘case1_MLP_ENDO_1_validated.h5?raw=true’ saved [70216/70216]
#
# --2020-09-27 04:33:24--  https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_RNN_ENDO_1_validated.h5?raw=true
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_RNN_ENDO_1_validated.h5 [following]
# --2020-09-27 04:33:25--  https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_RNN_ENDO_1_validated.h5
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_RNN_ENDO_1_validated.h5 [following]
# --2020-09-27 04:33:25--  https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_RNN_ENDO_1_validated.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41168 (40K) [application/octet-stream]
# Saving to: ‘case1_RNN_ENDO_1_validated.h5?raw=true’
#
# case1_RNN_ENDO_1_va 100%[===================>]  40.20K  --.-KB/s    in 0.01s
#
# 2020-09-27 04:33:25 (4.09 MB/s) - ‘case1_RNN_ENDO_1_validated.h5?raw=true’ saved [41168/41168]
#
# --2020-09-27 04:33:25--  https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_RNN_ENDO_1_NEW_validated.h5?raw=true
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_RNN_ENDO_1_NEW_validated.h5 [following]
# --2020-09-27 04:33:25--  https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_RNN_ENDO_1_NEW_validated.h5
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_RNN_ENDO_1_NEW_validated.h5 [following]
# --2020-09-27 04:33:25--  https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_RNN_ENDO_1_NEW_validated.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57348 (56K) [application/octet-stream]
# Saving to: ‘case1_RNN_ENDO_1_NEW_validated.h5?raw=true’
#
# case1_RNN_ENDO_1_NE 100%[===================>]  56.00K  --.-KB/s    in 0.01s
#
# 2020-09-27 04:33:26 (3.65 MB/s) - ‘case1_RNN_ENDO_1_NEW_validated.h5?raw=true’ saved [57348/57348]
#
# --2020-09-27 04:33:26--  https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_RNN_ENDO_2_validated.h5?raw=true
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_RNN_ENDO_2_validated.h5 [following]
# --2020-09-27 04:33:26--  https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_RNN_ENDO_2_validated.h5
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_RNN_ENDO_2_validated.h5 [following]
# --2020-09-27 04:33:26--  https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_RNN_ENDO_2_validated.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 73872 (72K) [application/octet-stream]
# Saving to: ‘case1_RNN_ENDO_2_validated.h5?raw=true’
#
# case1_RNN_ENDO_2_va 100%[===================>]  72.14K  --.-KB/s    in 0.02s
#
# 2020-09-27 04:33:27 (4.19 MB/s) - ‘case1_RNN_ENDO_2_validated.h5?raw=true’ saved [73872/73872]

# %% [markdown]
# case1_MLP_ENDO_1_validated.h5
#
# case1_RNN_ENDO_1_validated.h5
#
# case1_RNN_ENDO_1_NEW_validated.h5
#
# case1_RNN_ENDO_2_validated.h5

# %%
MLP_ENDO_1 = keras.models.Sequential()
MLP_ENDO_1 = keras.models.load_model('/content/case1_MLP_ENDO_1_validated.h5?raw=true')
keras.utils.plot_model(MLP_ENDO_1, show_shapes=True)

# %%
RNN_ENDO_1 = keras.models.Sequential()
RNN_ENDO_1 = keras.models.load_model('/content/case1_RNN_ENDO_1_validated.h5?raw=true')
keras.utils.plot_model(RNN_ENDO_1, show_shapes=True)

# %%
RNN_ENDO_1_NEW = keras.models.Sequential()
RNN_ENDO_1_NEW = keras.models.load_model('/content/case1_RNN_ENDO_1_NEW_validated.h5?raw=true')
keras.utils.plot_model(RNN_ENDO_1, show_shapes=True)

# %%
RNN_ENDO_2 = keras.models.Sequential()
RNN_ENDO_2 = keras.models.load_model('/content/case1_RNN_ENDO_2_validated.h5?raw=true')
keras.utils.plot_model(RNN_ENDO_1, show_shapes=True)

# %% [markdown]
# ### PREDIÇÕES COM OS MODELOS ENDOGENOS COM OS MENORES RMSE NA FASE EXPERIMENTAL

# %% [markdown]
# #### RNN_ENDO_2

# %%
#RNN_ENDO_2
model_name = 'RNN_ENDO_2'
model = RNN_ENDO_2
x_test = scaled_recurrent_test_x
pred_y = model.predict(x_test)
# retorna os valores a escala normal do problema
pred_y = recurrent_scalers[0].inverse_transform(pred_y) # 0 = ENTR_ALMOCO

reg = 'pred_' + model_name + '_testFINAL'
df_test[reg] = pred_y
df_models_metrics = metricas_predicoes(df_test, reg,df_models_metrics)
# Out:
# TOTAL DE REFEIÇÕES CONSUMIDAS = 31962 : 88 linhas
# TOTAL DE REFEIÇÕES PROJETADAS = 31465.611 : 88 linhas
# ERRO DE PREVISÃO = -496.388671875 -1.553058857002065 % do total consumido
# CORRELAÇÃO (r): 0.5954398951050144 Pi (p) :9.422151772316392e-10
# RMSE = 108.06630151129822
#          -4.56993282e-03,  6.39884844e-02, -1.28863692e-01]], dtype=float32)]

# %%
df_test['2019-05-10':'2019-06-10']['ENTR_ALMOCO']
# Out:
# DATA
# 2019-05-10    279
# 2019-05-13    393
# 2019-05-14    506
# 2019-05-15     19
# 2019-05-16    400
# 2019-05-17    268
# 2019-05-20    416
# 2019-05-21    459
# 2019-05-22    424
# 2019-05-23    439
# 2019-05-24    251
# 2019-05-27    434
# 2019-05-28    452
# 2019-05-29    428
# 2019-05-30     38
# 2019-05-31    270
# 2019-06-03     13
# 2019-06-04    195
# 2019-06-05    215
# 2019-06-06    162
# 2019-06-07    243
# 2019-06-10    419
# Name: ENTR_ALMOCO, dtype: int64

# %%
df_test['2019-03-01':'2019-03-10']['ENTR_ALMOCO']
# Out:
# DATA
# 2019-03-01    224
# 2019-03-07    387
# 2019-03-08    209
# Name: ENTR_ALMOCO, dtype: int64

# %% [markdown]
# #### DATAS OUTLIERS

# %% [markdown]
# ANOMALIA:
# 2019-03-08 --- 209 (SEXTA - FEIRA, NA SEMANA TEVE FERIADO NA TERÇA DIA 05, INICIO DO SEMESTRE)
#
# OUTLIERS:
# 2019-05-15 --- 19 (PARALIZAÇÃO)
#
# 2019-05-30 --- 38 (PARALIZAÇÃO)
#
# 2019-06-03 --- 13

# %% [markdown]
# #### MLP_ENDO_2

# %%
keras.utils.plot_model(MLP_ENDO_1, show_shapes=True)

# %%
model_name = 'MLP_ENDO_1'
model = MLP_ENDO_1
x_test = scaled_recurrent_test_x
pred_y = model.predict(x_test)
# retorna os valores a escala normal do problema
pred_y = recurrent_scalers[0].inverse_transform(pred_y) # 0 = ENTR_ALMOCO

reg = 'pred_' + model_name + '_testFINAL'
df_test[reg] = pred_y
df_models_metrics = metricas_predicoes(df_test, reg , df_models_metrics)
# Out:
# TOTAL DE REFEIÇÕES CONSUMIDAS = 31962 : 88 linhas
# TOTAL DE REFEIÇÕES PROJETADAS = 32369.654 : 88 linhas
# ERRO DE PREVISÃO = 407.654296875 1.2754342559132719 % do total consumido
# CORRELAÇÃO (r): 0.5212411617024483 Pi (p) :1.9211576129056944e-07
# RMSE = 128.05415759037942
# TOTAL DE REFEIÇÕES SUB PROJETADAS = -4305.512153625488
# TOTAL DE REFEIÇÕES SUPER PROJETADAS = 3897.8567390441895
# ERRO ABSOLUTO MEDIANO = 71.89508056640625
# ERRO ABSOLUTO PERCENTUAL MEDIO = 92.58158131858634%

# %%
MLP_ENDO_1.layers[1].get_weights()
# Out:
# [array([[-1.38481125e-01, -1.59126863e-01, -8.73689204e-02,
#          -2.39390656e-01,  5.33496626e-02,  2.26480380e-01,
#           1.57737777e-01,  1.87777415e-01,  1.60177380e-01,
#           2.47795835e-01, -6.79058656e-02,  8.88815373e-02,
#           3.17685604e-01, -8.44842046e-02, -6.41505867e-02,
#           1.37901381e-01, -5.31496294e-02, -2.23153949e-01,
#           4.82295118e-02,  1.37773957e-02, -4.74635251e-02,
#           3.39837745e-02, -1.12744078e-01, -7.03840405e-02,
#           1.67972267e-01, -2.76180267e-01,  1.50366649e-01,
#          4.5159515e-02, -5.5661928e-03, -4.1864906e-02,  1.6694276e-02,
#         -3.4289144e-03,  4.5269617e-04, -2.9769318e-02, -3.3424187e-02,
#          2.9688355e-02,  1.8624790e-02,  5.3095680e-02, -2.1976748e-02],
#        dtype=float32)]

# %% [markdown]
# ## IMPORTAÇÃO DOS MODELOS MISTOS (ENDÓGENOS E EXÓGENOS)

# %%
# !wget https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_RNN_EXO_1_validated.h5?raw=true
# !wget https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_RNN_EXO_2_validated.h5?raw=true
# !wget https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_RNN_EXO_3_validated.h5?raw=true
# Out:
# --2020-09-27 04:33:43--  https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_RNN_EXO_1_validated.h5?raw=true
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_RNN_EXO_1_validated.h5 [following]
# --2020-09-27 04:33:43--  https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_RNN_EXO_1_validated.h5
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_RNN_EXO_1_validated.h5 [following]
# --2020-09-27 04:33:43--  https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_RNN_EXO_1_validated.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 86280 (84K) [application/octet-stream]
# Saving to: ‘case1_RNN_EXO_1_validated.h5?raw=true’
#
# case1_RNN_EXO_1_val 100%[===================>]  84.26K  --.-KB/s    in 0.02s
#
# 2020-09-27 04:33:43 (4.78 MB/s) - ‘case1_RNN_EXO_1_validated.h5?raw=true’ saved [86280/86280]
#
# --2020-09-27 04:33:43--  https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_RNN_EXO_2_validated.h5?raw=true
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_RNN_EXO_2_validated.h5 [following]
# --2020-09-27 04:33:44--  https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_RNN_EXO_2_validated.h5
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_RNN_EXO_2_validated.h5 [following]
# --2020-09-27 04:33:44--  https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_RNN_EXO_2_validated.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 143680 (140K) [application/octet-stream]
# Saving to: ‘case1_RNN_EXO_2_validated.h5?raw=true’
#
# case1_RNN_EXO_2_val 100%[===================>] 140.31K  --.-KB/s    in 0.02s
#
# 2020-09-27 04:33:44 (6.53 MB/s) - ‘case1_RNN_EXO_2_validated.h5?raw=true’ saved [143680/143680]
#
# --2020-09-27 04:33:44--  https://github.com/ddlandim/monografy-ann-demand-prediction/blob/master/Models/case1_RNN_EXO_3_validated.h5?raw=true
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_RNN_EXO_3_validated.h5 [following]
# --2020-09-27 04:33:45--  https://github.com/ddlandim/monografy-ann-demand-prediction/raw/master/Models/case1_RNN_EXO_3_validated.h5
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_RNN_EXO_3_validated.h5 [following]
# --2020-09-27 04:33:45--  https://raw.githubusercontent.com/ddlandim/monografy-ann-demand-prediction/master/Models/case1_RNN_EXO_3_validated.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 143472 (140K) [application/octet-stream]
# Saving to: ‘case1_RNN_EXO_3_validated.h5?raw=true’
#
# case1_RNN_EXO_3_val 100%[===================>] 140.11K  --.-KB/s    in 0.02s
#
# 2020-09-27 04:33:45 (5.94 MB/s) - ‘case1_RNN_EXO_3_validated.h5?raw=true’ saved [143472/143472]

# %%
RNN_EXO_1 = keras.models.Sequential()
RNN_EXO_1 = keras.models.load_model('/content/case1_RNN_EXO_1_validated.h5?raw=true')
keras.utils.plot_model(RNN_EXO_1, show_shapes=True)

# %%
RNN_EXO_2 = keras.models.Sequential()
RNN_EXO_2 = keras.models.load_model('/content/case1_RNN_EXO_2_validated.h5?raw=true')
keras.utils.plot_model(RNN_EXO_2, show_shapes=True)

# %%
RNN_EXO_3 = keras.models.Sequential()
RNN_EXO_3 = keras.models.load_model('/content/case1_RNN_EXO_3_validated.h5?raw=true')
keras.utils.plot_model(RNN_EXO_3, show_shapes=True)

# %% [markdown]
# ### PREDIÇÃO COM O MODELO MISTO COM O MENOR ERRO ABS MEDIO NA FASE EXPERIMENTAL

# %% [markdown]
# #### **RNN_EXO_2**

# %%
#RNN_EXO_2
model_name = 'RNN_EXO_2'
model = RNN_EXO_2
x_test = (scaled_recurrent_test_x, scaled_discrete_test_x)
pred_y = model.predict(x_test)
# retorna os valores a escala normal do problema
pred_y = recurrent_scalers[0].inverse_transform(pred_y)

reg = 'pred_' + model_name + '_testFINAL'
df_test[reg] = pred_y
df_models_metrics = metricas_predicoes(df_test, reg , df_models_metrics)
# Out:
# TOTAL DE REFEIÇÕES CONSUMIDAS = 31962 : 88 linhas
# TOTAL DE REFEIÇÕES PROJETADAS = 30823.15 : 88 linhas
# ERRO DE PREVISÃO = -1138.849609375 -3.5631362535980227 % do total consumido
# CORRELAÇÃO (r): 0.5206433708658167 Pi (p) :1.9952072030259878e-07
# RMSE = 112.99211175918882
# TOTAL DE REFEIÇÕES SUB PROJETADAS = -3044.8836059570312
# TOTAL DE REFEIÇÕES SUPER PROJETADAS = 4183.733709335327
# ERRO ABSOLUTO MEDIANO = 63.59893035888672
# ERRO ABSOLUTO PERCENTUAL MEDIO = 88.26875246320391%

# %%
RNN_EXO_2.get_weights()
# Out:
# [array([[ 2.38510400e-01, -2.68355489e-01, -2.65987992e-01,
#           7.90596604e-02, -3.12755257e-02, -7.24247098e-02,
#          -1.74906597e-01, -1.31450891e-01, -6.98916093e-02,
#          -2.95824438e-01, -4.53065693e-01,  1.04567140e-01,
#          -2.97546566e-01, -2.47707605e-01,  8.90834183e-02,
#           4.68435138e-02,  3.37012038e-02,  2.64133155e-01,
#           1.72135413e-01, -5.95483370e-02,  8.29740092e-02,
#           2.11197451e-01, -1.63054273e-01,  3.15154530e-02,
#           1.22764982e-01,  1.27493694e-01, -2.78242409e-01,
#          -1.19276777e-01,  1.23098969e-01,  9.43512768e-02,
#          -1.81371167e-01, -9.82983261e-02,  1.59665123e-01,
#           3.42978910e-02,  1.26674145e-01, -4.57956409e-03,
#           2.52125505e-02,  1.53911680e-01,  5.46831526e-02,
#          -8.66961926e-02, -1.52445495e-01,  6.87456429e-02,
#          -5.44159822e-02,  1.73703998e-01, -2.73764759e-01,
#           3.97198983e-02,  1.65414438e-01, -1.15072548e-01,
#           2.28225328e-02, -7.40526542e-02,  8.09494630e-02,
#          -2.89725326e-02,  6.99699819e-02,  1.20935306e-01,
#           1.99121773e-01, -7.45188892e-02, -1.21587992e-01,
#           1.07454821e-01,  1.86264142e-01,  2.65583601e-02,
#          -1.85161650e-01,  1.19060300e-01, -8.07590038e-02,
#           8.61773640e-02,  2.13579476e-01,  2.50731528e-01,
#          -2.07073390e-02, -8.36098120e-02,  2.87848443e-01,
#           3.12176533e-02,  3.54962870e-02,  2.01708332e-01,
#          -1.13293469e-01,  1.60951853e-01,  2.57591188e-01,
#           0.3425257 , -0.26093668, -0.19630028, -0.21217534,  0.31365892,
#           0.10679728, -0.34161943, -0.2921555 , -0.00357447,  0.08204624,
#          -0.3604323 ],
#         [-0.03683091, -0.21496364, -0.03481506, -0.12847064,  0.20686965,
#           0.00289582, -0.10999877,  0.3090146 ,  0.33800092, -0.11612172,
#          -0.27018967, -0.19948743,  0.0520668 , -0.20400277, -0.4033444 ,
#          -0.1755    ],
#         [-0.07905319, -0.20577475, -0.2444561 ,  0.32544303, -0.32421353,
#           0.10216296,  0.25571126,  0.26667082, -0.28208533, -0.10757775,
#           0.10068794, -0.19483678,  0.16384427, -0.17991243, -0.33248332,
#           0.25088683],
#         [ 0.12936257, -0.1660633 ,  0.07065018,  0.2294944 , -0.22254974,
#          -0.06205966, -0.20823301,  0.28369847,  0.00950684,  0.28838295,
#           0.25137964, -0.20569298,  0.09634817,  0.22703132,  0.29298717,
#          -0.26864251],
#         [-0.15453148,  0.2609554 ,  0.16519542,  0.16778861, -0.06475324,
#           0.11770051,  0.17368402, -0.32067138, -0.16526358,  0.35465056,
#          -0.45453578, -0.10556901, -0.03799365, -0.2824935 , -0.29651877,
#           0.27809972],
#         [-0.03629876,  0.19493176,  0.31806362,  0.31539866, -0.06142142,
#          -0.25271624, -0.13453826, -0.08508144,  0.21872684,  0.02797725,
#           0.01050217, -0.16650775, -0.04267902,  0.11050339,  0.16039757,
#          -0.20591061],
#         [ 0.32094505, -0.33882976, -0.2918031 ,  0.17679523, -0.22655323,
#          -0.03056584,  0.07510199,  0.21906234, -0.04149818, -0.02343217,
#           0.04809094,  0.05256928,  0.17561603,  0.30274048, -0.13785012,
#          -0.0209171 ],
#         [ 0.2254448 , -0.22684005,  0.31213087, -0.04830031, -0.35829598,
#          -0.15246217, -0.01667704,  0.32344007,  0.0204725 , -0.29225484,
#           0.05277683,  0.04648443,  0.14101505, -0.12245899,  0.34201798,
#           0.3542108 ],
#         [ 0.12702283,  0.16274658, -0.00299454, -0.21416727,  0.35186103,
#           0.11075836, -0.01498505, -0.10538313, -0.20579201, -0.12713327,
#          -0.35088018, -0.22113718, -0.26044527, -0.31447524,  0.03133795,
#          -0.03415015],
#         [ 0.2523987 , -0.27527887, -0.21471265, -0.03665173,  0.314612  ,
#          -0.23278278, -0.2846088 ,  0.18708572, -0.05516922, -0.03924984,
#           0.11674619,  0.06527561,  0.1662952 , -0.34315762, -0.10476847,
#           0.20191011],
#         [-0.00871494, -0.12324581,  0.25734308, -0.2649536 , -0.16698809,
#          -0.16599713,  0.27349165,  0.25885   ,  0.0788528 ,  0.27804855,
#           0.05400747, -0.01116875, -0.29851466, -0.01761097,  0.27543166,
#          -0.23749438],
#         [-0.21220775, -0.19859068,  0.03600603,  0.13744126,  0.19281639,
#          -0.20107435, -0.10272173,  0.19410852, -0.25648803, -0.00642841,
#           0.29023728,  0.07120388, -0.00828626,  0.25930333,  0.24398689,
#           0.1600083 ],
#         [ 0.11252496,  0.16521531,  0.12237801, -0.10143402,  0.19388263,
#          -0.27140138,  0.0459962 , -0.16555808,  0.35428113,  0.09415402,
#          -0.16723913,  0.30564746,  0.25465274,  0.27494085,  0.16531137,
#           0.09548546],
#         [ 0.17673464,  0.21127255,  0.15064764, -0.06777459, -0.14239597,
#          -0.22946529,  0.00083892, -0.07549895, -0.31306398,  0.347093  ,
#          -0.05585158, -0.2744921 , -0.32142314, -0.2764982 ,  0.24731642,
#          -0.08274497],
#         [ 0.31364834, -0.21934958, -0.08626838, -0.3319655 , -0.1441237 ,
#           0.15325564,  0.22502169, -0.24880648,  0.19743286,  0.22605185,
#          -0.06099663, -0.09680291,  0.07834969, -0.10297692,  0.04213624,
#           0.15722786],
#         [ 0.11134943,  0.23812267, -0.29048443,  0.15457645,  0.0526028 ,
#           0.26615462,  0.21889713,  0.29487905, -0.10463637,  0.18375441,
#          -0.14934601, -0.12054977, -0.00544149, -0.13238578, -0.31787524,
#          -0.08062109],
#         [ 0.05357036, -0.26872277, -0.03389004, -0.18258381,  0.06439237,
#           0.28694075,  0.2413937 ,  0.31216148, -0.16892742, -0.16349661,
#           0.07251428, -0.04460266, -0.12776776,  0.04670024,  0.07557046,
#          -0.05771862],
#         [ 0.18563308, -0.0830115 , -0.34122193, -0.13033655,  0.34046197,
#           0.2923417 ,  0.14331342,  0.20254225, -0.2931831 ,  0.20432122,
#          -0.14102201, -0.03591326, -0.12667926,  0.31120536,  0.00374726,
#           0.29859468],
#         [ 0.27846625, -0.06929418,  0.01940269,  0.028664  , -0.2527677 ,
#           0.09331804, -0.3771937 ,  0.3766373 , -0.3156359 , -0.25590548,
#           0.36787352,  0.0424953 , -0.11227329,  0.20027432, -0.21147169,
#           0.34602696],
#         [ 0.29777178,  0.07106292, -0.12649278,  0.1149036 ,  0.24346857,
#           0.21900274,  0.10074739, -0.27675134,  0.34282178, -0.04458025,
#          -0.09403022, -0.05568931, -0.10595979, -0.26233974, -0.24109828,
#           0.10494464],
#         [-0.13630821, -0.2554873 , -0.221919  , -0.07126546,  0.3085899 ,
#          -0.13012871,  0.00656616,  0.3015563 , -0.06915709,  0.25804207,
#           0.06373626, -0.03228971, -0.13393149, -0.3126818 ,  0.19345589,
#          -0.02081629],
#         [ 0.13148834,  0.04670534, -0.10412662,  0.16858569,  0.05683953,
#           0.19929744, -0.2790332 , -0.07393849,  0.10489684,  0.09388923,
#          -0.27759522,  0.00886349,  0.34815964,  0.02825681, -0.25302926,
#          -0.26324365],
#         [ 0.12391695,  0.14002085,  0.06197357, -0.2625665 ,  0.28551313,
#          -0.26779956, -0.27830416,  0.26764295, -0.05229548,  0.34004715,
#           0.2417567 ,  0.13509557, -0.18943912, -0.02144888,  0.15898696,
#          -0.14491215],
#         [-0.28981224,  0.25494927, -0.20072629,  0.05011152,  0.35360074,
#          -0.33307782, -0.29195097, -0.02579604, -0.2813057 ,  0.0553656 ,
#           0.2709435 ,  0.06221501,  0.35183385,  0.22116202, -0.09917768,
#          -0.01624472],
#         [ 0.1870893 ,  0.41823518,  0.13527909, -0.2681421 , -0.01192047,
#          -0.34126222,  0.37103945, -0.41480404,  0.10541458, -0.06171688,
#          -0.43316793,  0.33936313,  0.14029175,  0.43740276,  0.06669261,
#          -0.20361714],
#         [ 0.35643834,  0.26394105, -0.2900311 ,  0.21035732,  0.25933576,
#           0.36395437, -0.08159766,  0.27314523, -0.23496929, -0.16111995,
#           0.29163086, -0.33784238,  0.07446802, -0.15955395, -0.10812157,
#          -0.20690815],
#         [-0.22255336, -0.3154731 , -0.06916752, -0.17281087, -0.38126108,
#           0.238409  , -0.19177723,  0.32144007,  0.3325918 , -0.27421987,
#           0.2285009 , -0.21781482, -0.3458051 , -0.151727  ,  0.345164  ,
#          -0.06187315],
#         [-0.11955916,  0.25846076, -0.10114833,  0.1354104 ,  0.31168514,
#          -0.37090492,  0.23822626,  0.2588375 ,  0.11302973, -0.221192  ,
#           0.10453419, -0.08483208, -0.18815874,  0.02907642, -0.3456143 ,
#           0.33431807],
#         [-0.4288516 , -0.21157724, -0.32076046, -0.60845715,  0.12760472,
#           0.43325698, -0.00880597,  0.2178009 ,  0.04392905,  0.17438377,
#           0.25163454,  0.11121693,  0.27725694,  0.15302356, -0.19498271,
#          -0.3896363 ]], dtype=float32),
#  array([ 0.00426381,  0.000135  ,  0.06837347,  0.00708584, -0.02698576,
#          0.02254586,  0.03547039, -0.00684361, -0.00498448,  0.013075  ,
#         -0.02366537, -0.01011852, -0.01093967,  0.00423709,  0.00835843,
#          0.00648806], dtype=float32),
#  array([[-0.02658662],
#         [ 0.01623038],
#         [-0.13130043],
#         [-0.09059712],
#         [-0.06659035],
#         [-0.3908394 ],
#         [ 0.43181485],
#         [ 0.12646674],
#         [-0.13057953],
#         [-0.3795393 ],
#         [ 0.3304956 ],
#         [-0.07784618],
#         [ 0.23064348],
#         [ 0.00259008],
#         [-0.27330837],
#         [-0.11626606],
#         [ 0.41988936],
#         [ 0.13201162],
#         [ 0.30557248],
#         [ 0.41847572],
#         [-0.24513991],
#         [ 0.23169068],
#         [ 0.1751081 ],
#         [-0.20418042],
#         [-0.3538231 ],
#         [-0.10921155],
#         [-0.33263415],
#         [-0.14696297],
#         [-0.30284888],
#         [ 0.1402347 ],
#         [ 0.3344595 ],
#         [ 0.11182714]], dtype=float32),
#  array([0.00450079], dtype=float32)]

# %%
df_models_metrics.to_excel('/content/case1_df_models_metrics.xlsx')

# %%
df_test
# Out:
#             SEMESTRE_1  ...  pred_RNN_EXO_2_testFINAL
# DATA                    ...
# 2019-02-20           1  ...                387.503998
# 2019-02-21           1  ...                388.437286
# 2019-02-22           1  ...                348.338867
# 2019-02-25           1  ...                226.436829
# 2019-02-26           1  ...                258.375488
# ...                ...  ...                       ...
# 2019-07-01           1  ...                230.292572
# 2019-07-02           1  ...                178.844254
# 2019-07-03           1  ...                156.752380
# 2019-07-04           1  ...                174.423950
# 2019-07-05           1  ...                 18.642694
#
# [88 rows x 46 columns]

# %%
df_test.to_excel('/content/case1_df_test.xlsx')

# %% [markdown]
# # Download xlsx files in /content/ folder and enjoy it =)
